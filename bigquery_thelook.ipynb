# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Packages

# %%
import pandas as pd

# %% [markdown]
# # Example 2: Query a table with BigQuery DataFrames

# %%
# With BigQuery DataFrames, you can use many familiar Pandas methods, but the
# processing happens BigQuery rather than the runtime, allowing you to work with larger
# DataFrames that would otherwise not fit in the runtime memory.
# Learn more here: https://cloud.google.com/python/docs/reference/bigframes/latest

import bigframes.pandas as bf

bf.options.bigquery.location = "US" #this variable is set based on the dataset you chose to query
bf.options.bigquery.project = "inernship-1206" #this variable is set based on the dataset you chose to query

# %%
query_users = """
SELECT id, first_name, last_name, email, created_at
FROM `bigquery-public-data.thelook_ecommerce.users`
"""

query_products = """
SELECT id, name, category, retail_price
FROM `bigquery-public-data.thelook_ecommerce.products`
"""

df_users = pd.DataFrame(bf.read_gbq(query_users))
df_products = pd.DataFrame(bf.read_gbq(query_products))

df_products.columns = ["id", "name", "category", "retail_price"]
df_users.columns = ["id", "first_name", "last_name", "email", "created_at"]
# Out:
# Query job 1762794f-2029-417e-a1f0-c6eb8ecbc12d is DONE. 5.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:1762794f-2029-417e-a1f0-c6eb8ecbc12d&page=queryresults">Open Job</a>
# Query job e6e86db5-9cb9-4c20-bbc8-a7df5a006253 is DONE. 5.8 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:e6e86db5-9cb9-4c20-bbc8-a7df5a006253&page=queryresults">Open Job</a>
# Query job 287b0333-0506-44bf-bbf6-b4a5ba0c842d is DONE. 2.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:287b0333-0506-44bf-bbf6-b4a5ba0c842d&page=queryresults">Open Job</a>
# Query job 73e4c074-8cd9-4c96-9d56-16fc9c0a4c70 is DONE. 2.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:73e4c074-8cd9-4c96-9d56-16fc9c0a4c70&page=queryresults">Open Job</a>

# %%
query_orders = """
SELECT order_id, user_id, created_at, num_of_item
FROM `bigquery-public-data.thelook_ecommerce.orders`
WHERE status='Complete'
"""

query_orderDetails = """
SELECT id, order_id, product_id
FROM `bigquery-public-data.thelook_ecommerce.order_items`
WHERE status='Complete'
"""

df_orders = pd.DataFrame(bf.read_gbq(query_orders))
df_orderDetails = pd.DataFrame(bf.read_gbq(query_orderDetails))

df_orders.columns = ["order_id", "user_id", "created_at", "num_of_item"]
df_orderDetails.columns = ["id", "order_id", "product_id"]
# Out:
# Query job 1ae6d6e5-9cd9-4aef-bc23-5024f300eadc is DONE. 5.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:1ae6d6e5-9cd9-4aef-bc23-5024f300eadc&page=queryresults">Open Job</a>
# Query job 34e7f4e4-5599-4127-bb52-123d26ca3d24 is DONE. 1.0 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:34e7f4e4-5599-4127-bb52-123d26ca3d24&page=queryresults">Open Job</a>
# Query job da653ab1-eadf-4699-ae29-2006ed8b62c7 is DONE. 6.2 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:da653ab1-eadf-4699-ae29-2006ed8b62c7&page=queryresults">Open Job</a>
# Query job 75ce3549-0b11-4af6-9447-eb83aba0a41d is DONE. 1.1 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=inernship-1206&j=bq:US:75ce3549-0b11-4af6-9447-eb83aba0a41d&page=queryresults">Open Job</a>

# %%
df_products_10 = df_products.sample(10)

# %%
df_users.shape
# Out:
# (100000, 5)

# %%
df_products_10.set_index("id", inplace=True)

# %%
df_products_10
# Out:
#                                                     name  \
# id
# 23566                           Menâ€™s Denim Work Short
# 22780                    Carhartt Men's Denim Work Short
# 12691              Fashion Essentials Bra Back Converter
# 7826        Calvin Klein Jeans Women's Cinch Back Jacket
# 8254                   Anne Klein Casa Blanca Skirt Suit
# 15707            Pure Cashmere Men and Women Solid Scarf
# 2175   Life is good. Womens Softwash Hoodie - LIG - S...
# 13094  Speedo Women's Speedo Women'S Race Endurance+ ...
# 9989            Hue Sleepwear Women's Misty Leopard Pant
# 15428  Glamorise Women's MagicLift Full-Figure Suppor...
#
#                             category retail_price
# id
# 23566                         Shorts         36.0
# 22780                         Shorts         47.0
# 12691                      Intimates          6.9
# 7826               Blazers & Jackets         89.5
# 8254                           Suits   186.369995
# 15707                           Plus    47.990002
# 2175   Fashion Hoodies & Sweatshirts         63.0
# 13094                           Swim    70.160004
# 9989                  Sleep & Lounge         25.0
# 15428                           Plus         40.0

# %%
print(df_products_10.loc[15428, "name"])
# Out:
# Glamorise Women's MagicLift Full-Figure Support Bra #1000

# %%
df_orderDetails.columns
# Out:
# Index(['id', 'order_id', 'product_id'], dtype='object')

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'created_at', 'num_of_item'], dtype='object')

# %%
orders_5_1 = list(df_orders[df_orders.num_of_item>1].sample(5).order_id)
orders_5_2 = list(df_orders[df_orders.num_of_item==1].sample(5).order_id)

# %%
print(df_orderDetails[df_orderDetails.order_id.isin(orders_5_1)].shape, 
      df_orderDetails[df_orderDetails.order_id.isin(orders_5_2)].shape)
# Out:
# (12, 3) (5, 3)

# %%
print(df_orderDetails[df_orderDetails.order_id.isin(orders_5_1)].product_id.nunique(), 
      df_orderDetails[df_orderDetails.order_id.isin(orders_5_2)].product_id.nunique())
# Out:
# 12 5

# %%
df_products.set_index("id", inplace=True)

# %%
df_products_1 = df_products[df_products.index.isin(list(df_orderDetails[df_orderDetails.order_id.isin(orders_5_1)].product_id.unique()) +
                                list(df_orderDetails[df_orderDetails.order_id.isin(orders_5_2)].product_id.unique()))]
df_products_1
# Out:
#                                                     name             category  \
# id
# 18447                  C-IN2 Men's Pop Color Street Jock               Active
# 9780                Carole Hochman Women's Long Zip Robe       Sleep & Lounge
# 26122    Harbor Bay Big & Tall 2-Pack Plaid Woven Boxers            Underwear
# 20204  Ralph Lauren Mens SB 2B Solid Navy Blue Wool Suit  Suits & Sport Coats
# 9738          Aimee Gowns Original Bra-less Nursing Gown       Sleep & Lounge
# 25329                Premium White Above Ankle Toe Socks                Socks
# 8267                  Mod-O-Doc Women's Big Cord Peacoat    Outerwear & Coats
# 21571            True Religion Men's Geno Baja Slim Jean                Jeans
# 8728   Larry Levine Women's Maxi Length Hooded Down J...    Outerwear & Coats
# 27032            HUGO BOSS Men's Woven Long Elastic Pant       Sleep & Lounge
# 19469  Michael Kors Men's Waffle Stitch Full Zip With...             Sweaters
# 24683       HUGO BOSS Men's Contrasting Stripe Crew Sock                Socks
# 18291  Duofold Men's Big-Tall Heavy Weight Plus Crew ...               Active
# 4171   Allegra K Ladies Elastic Waist Sleeveless Side...  Jumpsuits & Rompers
# 9129                  KEEN Concord Stripe Crew Lite Sock      Socks & Hosiery
# 3212           Bobi Women's Modal Jersey Cowl Neck Dress              Dresses
# 28832       Oakley Men's Flak Jacket XLJ Golf Sunglasses          Accessories
#
#       retail_price
# id
# 18447         17.0
# 9780          79.0
# 26122         23.0
# 20204    319.98999
# 9738     39.950001
# 25329          7.5
# 8267         170.0
# 21571        264.0
# 8728        118.75
# 27032    34.299999
# 19469   185.850006
# 24683         13.0
# 18291        33.98
# 4171         10.21
# 9129          17.0
# 3212          60.0
# 28832        150.0

# %%
df_orders.set_index("order_id", inplace=True)

# %%
users = list(df_orders[df_orders.index.isin(orders_5_1+orders_5_2)].user_id.unique())

# %%
df_users.set_index("id", inplace=True)
df_users[df_users.index.isin(users)]
# Out:
#       first_name last_name                         email  \
# id
# 79323   Michelle  Gonzalez  michellegonzalez@example.net
# 17080     Lauren    Butler      laurenbutler@example.org
# 3237      Daniel      Hunt        danielhunt@example.com
# 72897      James     Clark        jamesclark@example.org
# 63400  Stephanie    Monroe   stephaniemonroe@example.net
# 27927    Cynthia   Shelton    cynthiashelton@example.org
# 64878    Anthony      Wong       anthonywong@example.org
# 48522       Fred   Hopkins       fredhopkins@example.org
# 16842      Glenn   Vasquez      glennvasquez@example.com
# 89318      Scott    Weaver       scottweaver@example.net
#
#                      created_at
# id
# 79323 2021-01-28 03:29:00+00:00
# 17080 2021-07-07 08:10:00+00:00
# 3237  2021-11-09 10:44:00+00:00
# 72897 2019-05-11 10:36:00+00:00
# 63400 2021-05-24 08:01:00+00:00
# 27927 2022-06-09 11:41:00+00:00
# 64878 2019-08-31 02:14:00+00:00
# 48522 2021-10-06 09:35:00+00:00
# 16842 2021-02-12 01:53:00+00:00
# 89318 2019-11-23 10:19:00+00:00

# %%
df_orderDetails[df_orderDetails.order_id.isin(orders_5_1+orders_5_2)].merge(df_products.reset_index()[["id","retail_price"]], left_on="product_id", right_on="id").groupby("order_id")[["retail_price"]].sum()
# Out:
#           retail_price
# order_id
# 4204        198.850006
# 21127       191.480000
# 21439        17.000000
# 34926       170.000000
# 60865        57.299999
# 79236       110.160001
# 81111       264.000000
# 91075        17.000000
# 99024       197.750000
# 111586      319.989990

# %%
df_orders[df_orders.index.isin(orders_5_1+orders_5_2)]
# Out:
#          user_id                created_at num_of_item
# order_id
# 79236      63400 2021-07-23 08:01:00+00:00           3
# 21127      16842 2024-02-18 01:53:00+00:00           3
# 81111      64878 2020-07-30 02:14:00+00:00           1
# 21439      17080 2023-03-27 08:10:00+00:00           1
# 91075      72897 2022-11-12 10:36:00+00:00           1
# 111586     89318 2024-04-04 10:19:00+00:00           1
# 4204        3237 2022-07-19 10:44:00+00:00           2
# 34926      27927 2023-11-04 11:41:00+00:00           1
# 60865      48522 2023-12-17 09:35:00+00:00           2
# 99024      79323 2022-03-06 03:29:00+00:00           2

# %%
df_orderDetails[df_orderDetails.order_id.isin(orders_5_1+orders_5_2)].merge(df_products.reset_index()[["id","retail_price"]], left_on="product_id", right_on="id")
# Out:
#       id_x order_id product_id   id_y retail_price
# 0   115012    79236       9738   9738    39.950001
# 1    31032    21439       9129   9129         17.0
# 2    30577    21127      28832  28832        150.0
# 3   143521    99024       9780   9780         79.0
# 4   143522    99024       8728   8728       118.75
# 5   115011    79236       3212   3212         60.0
# 6    88376    60865      27032  27032    34.299999
# 7   161766   111586      20204  20204    319.98999
# 8    88377    60865      26122  26122         23.0
# 9    30576    21127      25329  25329          7.5
# 10  132102    91075      18447  18447         17.0
# 11  115013    79236       4171   4171        10.21
# 12  117693    81111      21571  21571        264.0
# 13    6168     4204      19469  19469   185.850006
# 14    6169     4204      24683  24683         13.0
# 15   30578    21127      18291  18291        33.98
# 16   50597    34926       8267   8267        170.0

# %%
df_products_1
# Out:
#                                                     name             category  \
# id
# 18447                  C-IN2 Men's Pop Color Street Jock               Active
# 9780                Carole Hochman Women's Long Zip Robe       Sleep & Lounge
# 26122    Harbor Bay Big & Tall 2-Pack Plaid Woven Boxers            Underwear
# 20204  Ralph Lauren Mens SB 2B Solid Navy Blue Wool Suit  Suits & Sport Coats
# 9738          Aimee Gowns Original Bra-less Nursing Gown       Sleep & Lounge
# 25329                Premium White Above Ankle Toe Socks                Socks
# 8267                  Mod-O-Doc Women's Big Cord Peacoat    Outerwear & Coats
# 21571            True Religion Men's Geno Baja Slim Jean                Jeans
# 8728   Larry Levine Women's Maxi Length Hooded Down J...    Outerwear & Coats
# 27032            HUGO BOSS Men's Woven Long Elastic Pant       Sleep & Lounge
# 19469  Michael Kors Men's Waffle Stitch Full Zip With...             Sweaters
# 24683       HUGO BOSS Men's Contrasting Stripe Crew Sock                Socks
# 18291  Duofold Men's Big-Tall Heavy Weight Plus Crew ...               Active
# 4171   Allegra K Ladies Elastic Waist Sleeveless Side...  Jumpsuits & Rompers
# 9129                  KEEN Concord Stripe Crew Lite Sock      Socks & Hosiery
# 3212           Bobi Women's Modal Jersey Cowl Neck Dress              Dresses
# 28832       Oakley Men's Flak Jacket XLJ Golf Sunglasses          Accessories
#
#       retail_price
# id
# 18447         17.0
# 9780          79.0
# 26122         23.0
# 20204    319.98999
# 9738     39.950001
# 25329          7.5
# 8267         170.0
# 21571        264.0
# 8728        118.75
# 27032    34.299999
# 19469   185.850006
# 24683         13.0
# 18291        33.98
# 4171         10.21
# 9129          17.0
# 3212          60.0
# 28832        150.0

# %%
df_users.sample(3)
# Out:
#           id first_name last_name                         email  \
# 59178  86462      Karen    Turner       karenturner@example.net
# 14610  70030     Lauren   Shepard     laurenshepard@example.com
# 99976   5940   Jennifer  Espinoza  jenniferespinoza@example.com
#
#                      created_at
# 59178 2022-11-05 08:02:00+00:00
# 14610 2020-10-26 14:27:00+00:00
# 99976 2021-04-04 09:05:00+00:00
